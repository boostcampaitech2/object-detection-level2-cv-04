# %%
import os
import copy
import torch
import detectron2
from detectron2.data import detection_utils as utils
from detectron2.utils.logger import setup_logger
setup_logger()

from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.engine import DefaultTrainer
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_test_loader, build_detection_train_loader

# %%
# Register Dataset
try:
    register_coco_instances('coco_trash_train', {}, '../dataset/train.json', '../dataset/')
except AssertionError:
    pass

try:
    register_coco_instances('coco_trash_test', {}, '../dataset/test.json', '../dataset/')
except AssertionError:
    pass

MetadataCatalog.get('coco_trash_train').thing_classes = ["General trash", "Paper", "Paper pack", "Metal", 
                                                         "Glass", "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing"]

# %%
# config 불러오기
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file('COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml'))

# %%
# config 수정하기
cfg.DATASETS.TRAIN = ('coco_trash_train',)
cfg.DATASETS.TEST = ('coco_trash_test',)

cfg.DATALOADER.NUM_WOREKRS = 2

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url('COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml')

cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.001
cfg.SOLVER.MAX_ITER = 15000
cfg.SOLVER.STEPS = (8000,12000)
cfg.SOLVER.GAMMA = 0.005
cfg.SOLVER.CHECKPOINT_PERIOD = 3000

cfg.OUTPUT_DIR = './output'

cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 10

cfg.TEST.EVAL_PERIOD = 3000

# %%
# mapper - input data를 어떤 형식으로 return할지 (따라서 augmnentation 등 데이터 전처리 포함 됨)
import detectron2.data.transforms as T

def MyMapper(dataset_dict):
    dataset_dict = copy.deepcopy(dataset_dict)
    image = utils.read_image(dataset_dict['file_name'], format='BGR')
    
    transform_list = [
        T.RandomFlip(prob=0.5, horizontal=False, vertical=True),
        T.RandomBrightness(0.8, 1.8),
        T.RandomContrast(0.6, 1.3)
    ]
    
    image, transforms = T.apply_transform_gens(transform_list, image)
    
    dataset_dict['image'] = torch.as_tensor(image.transpose(2,0,1).astype('float32'))
    
    annos = [
        utils.transform_instance_annotations(obj, transforms, image.shape[:2])
        for obj in dataset_dict.pop('annotations')
        if obj.get('iscrowd', 0) == 0
    ]
    
    instances = utils.annotations_to_instances(annos, image.shape[:2])
    dataset_dict['instances'] = utils.filter_empty_instances(instances)
    
    return dataset_dict

# %%
# trainer - DefaultTrainer를 상속
class MyTrainer(DefaultTrainer):
    
    @classmethod
    def build_train_loader(cls, cfg, sampler=None):
        return build_detection_train_loader(
        cfg, mapper = MyMapper, sampler = sampler
        )
    
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            os.makedirs('./output_eval', exist_ok = True)
            output_folder = './output_eval'
            
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

# %%
# train
os.makedirs(cfg.OUTPUT_DIR, exist_ok = True)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [09/16 14:17:27 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=11, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=40, bias=True)
#     )
#   )
# )
# [09/16 14:17:27 d2.data.datasets.coco]: Loaded 4883 images in COCO format from ../dataset/train.json
# [09/16 14:17:27 d2.data.build]: Removed 0 images with no usable annotations. 4883 images left.
# [09/16 14:17:28 d2.data.build]: Distribution of instances among all 10 categories:
# |   category    | #instances   |  category   | #instances   |  category  | #instances   |
# |:-------------:|:-------------|:-----------:|:-------------|:----------:|:-------------|
# | General trash | 3966         |    Paper    | 6352         | Paper pack | 897          |
# |     Metal     | 936          |    Glass    | 982          |  Plastic   | 2943         |
# |   Styrofoam   | 1263         | Plastic bag | 5178         |  Battery   | 159          |
# |   Clothing    | 468          |             |              |            |              |
# |     total     | 23144        |             |              |            |              |
# [09/16 14:17:28 d2.data.build]: Using training sampler TrainingSampler
# [09/16 14:17:28 d2.data.common]: Serializing 4883 elements to byte tensors and concatenating them all ...
# [09/16 14:17:28 d2.data.common]: Serialized dataset takes 2.17 MiB
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (11, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (11,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (40, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (40,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [09/16 14:17:28 d2.engine.train_loop]: Starting training from iteration 0
# /opt/ml/detection/detectron2/detectron2/modeling/roi_heads/fast_rcnn.py:103: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370156314/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   num_fg = fg_inds.nonzero().numel()
# [09/16 14:17:48 d2.utils.events]:  eta: 3:45:33  iter: 19  total_loss: 3.267  loss_cls: 2.437  loss_box_reg: 0.7491  loss_rpn_cls: 0.05972  loss_rpn_loc: 0.02993  time: 0.9080  data_time: 0.0450  lr: 1.9981e-05  max_mem: 6307M
# [09/16 14:18:00 d2.utils.events]:  eta: 3:01:15  iter: 39  total_loss: 2.957  loss_cls: 2.018  loss_box_reg: 0.7535  loss_rpn_cls: 0.07661  loss_rpn_loc: 0.02671  time: 0.7498  data_time: 0.0133  lr: 3.9961e-05  max_mem: 6307M
# [09/16 14:18:11 d2.utils.events]:  eta: 2:25:51  iter: 59  total_loss: 2.218  loss_cls: 1.266  loss_box_reg: 0.6683  loss_rpn_cls: 0.1095  loss_rpn_loc: 0.04988  time: 0.6913  data_time: 0.0120  lr: 5.9941e-05  max_mem: 6307M
# [09/16 14:18:23 d2.utils.events]:  eta: 2:24:45  iter: 79  total_loss: 1.727  loss_cls: 0.8106  loss_box_reg: 0.6945  loss_rpn_cls: 0.06041  loss_rpn_loc: 0.03994  time: 0.6633  data_time: 0.0119  lr: 7.9921e-05  max_mem: 6307M
# [09/16 14:18:35 d2.utils.events]:  eta: 2:24:25  iter: 99  total_loss: 1.556  loss_cls: 0.7492  loss_box_reg: 0.7047  loss_rpn_cls: 0.0751  loss_rpn_loc: 0.04424  time: 0.6466  data_time: 0.0116  lr: 9.9901e-05  max_mem: 6307M
# [09/16 14:18:46 d2.utils.events]:  eta: 2:24:10  iter: 119  total_loss: 1.401  loss_cls: 0.6954  loss_box_reg: 0.672  loss_rpn_cls: 0.02741  loss_rpn_loc: 0.01579  time: 0.6355  data_time: 0.0121  lr: 0.00011988  max_mem: 6307M
# [09/16 14:18:58 d2.utils.events]:  eta: 2:23:59  iter: 139  total_loss: 1.444  loss_cls: 0.6711  loss_box_reg: 0.7185  loss_rpn_cls: 0.02788  loss_rpn_loc: 0.01781  time: 0.6277  data_time: 0.0120  lr: 0.00013986  max_mem: 6307M
# [09/16 14:19:10 d2.utils.events]:  eta: 2:23:43  iter: 159  total_loss: 1.467  loss_cls: 0.6921  loss_box_reg: 0.7284  loss_rpn_cls: 0.02825  loss_rpn_loc: 0.0187  time: 0.6216  data_time: 0.0114  lr: 0.00015984  max_mem: 6307M
# [09/16 14:19:21 d2.utils.events]:  eta: 2:23:32  iter: 179  total_loss: 1.54  loss_cls: 0.7067  loss_box_reg: 0.7437  loss_rpn_cls: 0.03204  loss_rpn_loc: 0.02509  time: 0.6170  data_time: 0.0118  lr: 0.00017982  max_mem: 6307M
# [09/16 14:19:33 d2.utils.events]:  eta: 2:23:17  iter: 199  total_loss: 1.387  loss_cls: 0.6398  loss_box_reg: 0.7002  loss_rpn_cls: 0.02635  loss_rpn_loc: 0.03676  time: 0.6134  data_time: 0.0124  lr: 0.0001998  max_mem: 6307M
# [09/16 14:19:45 d2.utils.events]:  eta: 2:23:12  iter: 219  total_loss: 1.269  loss_cls: 0.5848  loss_box_reg: 0.6868  loss_rpn_cls: 0.02536  loss_rpn_loc: 0.01426  time: 0.6110  data_time: 0.0131  lr: 0.00021978  max_mem: 6307M
# [09/16 14:19:56 d2.utils.events]:  eta: 2:23:02  iter: 239  total_loss: 1.368  loss_cls: 0.5771  loss_box_reg: 0.659  loss_rpn_cls: 0.02996  loss_rpn_loc: 0.0383  time: 0.6088  data_time: 0.0127  lr: 0.00023976  max_mem: 6307M
# [09/16 14:20:08 d2.utils.events]:  eta: 2:22:51  iter: 259  total_loss: 1.248  loss_cls: 0.5422  loss_box_reg: 0.6426  loss_rpn_cls: 0.01965  loss_rpn_loc: 0.02311  time: 0.6071  data_time: 0.0117  lr: 0.00025974  max_mem: 6307M
# [09/16 14:20:20 d2.utils.events]:  eta: 2:22:41  iter: 279  total_loss: 1.245  loss_cls: 0.5431  loss_box_reg: 0.6698  loss_rpn_cls: 0.03092  loss_rpn_loc: 0.02137  time: 0.6055  data_time: 0.0130  lr: 0.00027972  max_mem: 6307M
# [09/16 14:20:31 d2.utils.events]:  eta: 2:22:28  iter: 299  total_loss: 1.268  loss_cls: 0.6045  loss_box_reg: 0.6367  loss_rpn_cls: 0.02933  loss_rpn_loc: 0.03296  time: 0.6038  data_time: 0.0116  lr: 0.0002997  max_mem: 6307M
# [09/16 14:20:43 d2.utils.events]:  eta: 2:22:16  iter: 319  total_loss: 1.356  loss_cls: 0.6039  loss_box_reg: 0.6328  loss_rpn_cls: 0.02765  loss_rpn_loc: 0.02604  time: 0.6024  data_time: 0.0123  lr: 0.00031968  max_mem: 6307M
# [09/16 14:20:55 d2.utils.events]:  eta: 2:22:03  iter: 339  total_loss: 1.337  loss_cls: 0.6093  loss_box_reg: 0.6015  loss_rpn_cls: 0.03724  loss_rpn_loc: 0.03885  time: 0.6011  data_time: 0.0117  lr: 0.00033966  max_mem: 6307M
# [09/16 14:21:06 d2.utils.events]:  eta: 2:21:52  iter: 359  total_loss: 1.103  loss_cls: 0.5223  loss_box_reg: 0.536  loss_rpn_cls: 0.02734  loss_rpn_loc: 0.01873  time: 0.6005  data_time: 0.0144  lr: 0.00035964  max_mem: 6307M
# [09/16 14:21:18 d2.utils.events]:  eta: 2:21:40  iter: 379  total_loss: 1.138  loss_cls: 0.5351  loss_box_reg: 0.4783  loss_rpn_cls: 0.02554  loss_rpn_loc: 0.02837  time: 0.5996  data_time: 0.0121  lr: 0.00037962  max_mem: 6307M
# [09/16 14:21:30 d2.utils.events]:  eta: 2:21:29  iter: 399  total_loss: 1.046  loss_cls: 0.5106  loss_box_reg: 0.4257  loss_rpn_cls: 0.02943  loss_rpn_loc: 0.02889  time: 0.5988  data_time: 0.0133  lr: 0.0003996  max_mem: 6307M
# [09/16 14:21:42 d2.utils.events]:  eta: 2:21:17  iter: 419  total_loss: 1.109  loss_cls: 0.5301  loss_box_reg: 0.4388  loss_rpn_cls: 0.0304  loss_rpn_loc: 0.04246  time: 0.5980  data_time: 0.0122  lr: 0.00041958  max_mem: 6307M
# [09/16 14:21:53 d2.utils.events]:  eta: 2:21:05  iter: 439  total_loss: 0.9765  loss_cls: 0.4774  loss_box_reg: 0.3975  loss_rpn_cls: 0.02754  loss_rpn_loc: 0.02244  time: 0.5972  data_time: 0.0123  lr: 0.00043956  max_mem: 6307M
# [09/16 14:22:05 d2.utils.events]:  eta: 2:20:51  iter: 459  total_loss: 1.039  loss_cls: 0.531  loss_box_reg: 0.4372  loss_rpn_cls: 0.02798  loss_rpn_loc: 0.03662  time: 0.5964  data_time: 0.0117  lr: 0.00045954  max_mem: 6307M
# [09/16 14:22:16 d2.utils.events]:  eta: 2:20:39  iter: 479  total_loss: 0.9522  loss_cls: 0.4539  loss_box_reg: 0.398  loss_rpn_cls: 0.02609  loss_rpn_loc: 0.03145  time: 0.5960  data_time: 0.0142  lr: 0.00047952  max_mem: 6307M
# [09/16 14:22:28 d2.utils.events]:  eta: 2:20:27  iter: 499  total_loss: 1.083  loss_cls: 0.5247  loss_box_reg: 0.408  loss_rpn_cls: 0.0343  loss_rpn_loc: 0.0295  time: 0.5954  data_time: 0.0127  lr: 0.0004995  max_mem: 6307M
# [09/16 14:22:40 d2.utils.events]:  eta: 2:20:16  iter: 519  total_loss: 0.9056  loss_cls: 0.4926  loss_box_reg: 0.3597  loss_rpn_cls: 0.02422  loss_rpn_loc: 0.02698  time: 0.5951  data_time: 0.0151  lr: 0.00051948  max_mem: 6307M
# [09/16 14:22:51 d2.utils.events]:  eta: 2:20:03  iter: 539  total_loss: 0.9696  loss_cls: 0.5336  loss_box_reg: 0.3713  loss_rpn_cls: 0.02485  loss_rpn_loc: 0.02701  time: 0.5945  data_time: 0.0121  lr: 0.00053946  max_mem: 6307M
# [09/16 14:23:03 d2.utils.events]:  eta: 2:19:49  iter: 559  total_loss: 0.9388  loss_cls: 0.499  loss_box_reg: 0.3606  loss_rpn_cls: 0.03346  loss_rpn_loc: 0.03412  time: 0.5940  data_time: 0.0125  lr: 0.00055944  max_mem: 6307M
# [09/16 14:23:15 d2.utils.events]:  eta: 2:19:38  iter: 579  total_loss: 1.061  loss_cls: 0.5765  loss_box_reg: 0.4108  loss_rpn_cls: 0.04086  loss_rpn_loc: 0.03301  time: 0.5937  data_time: 0.0150  lr: 0.00057942  max_mem: 6307M
# [09/16 14:23:26 d2.utils.events]:  eta: 2:19:25  iter: 599  total_loss: 0.8528  loss_cls: 0.4641  loss_box_reg: 0.3261  loss_rpn_cls: 0.0336  loss_rpn_loc: 0.02551  time: 0.5932  data_time: 0.0129  lr: 0.0005994  max_mem: 6307M
# [09/16 14:23:38 d2.utils.events]:  eta: 2:19:12  iter: 619  total_loss: 0.9901  loss_cls: 0.5368  loss_box_reg: 0.3307  loss_rpn_cls: 0.0308  loss_rpn_loc: 0.03062  time: 0.5927  data_time: 0.0123  lr: 0.00061938  max_mem: 6307M
# [09/16 14:23:50 d2.utils.events]:  eta: 2:19:00  iter: 639  total_loss: 0.7968  loss_cls: 0.4454  loss_box_reg: 0.2922  loss_rpn_cls: 0.02286  loss_rpn_loc: 0.02153  time: 0.5923  data_time: 0.0121  lr: 0.00063936  max_mem: 6307M
# [09/16 14:24:01 d2.utils.events]:  eta: 2:18:46  iter: 659  total_loss: 0.9865  loss_cls: 0.5528  loss_box_reg: 0.3684  loss_rpn_cls: 0.03022  loss_rpn_loc: 0.03896  time: 0.5919  data_time: 0.0125  lr: 0.00065934  max_mem: 6307M
# [09/16 14:24:13 d2.utils.events]:  eta: 2:18:34  iter: 679  total_loss: 0.8434  loss_cls: 0.478  loss_box_reg: 0.3382  loss_rpn_cls: 0.02561  loss_rpn_loc: 0.0213  time: 0.5915  data_time: 0.0129  lr: 0.00067932  max_mem: 6307M
# [09/16 14:24:24 d2.utils.events]:  eta: 2:18:22  iter: 699  total_loss: 0.8759  loss_cls: 0.4944  loss_box_reg: 0.3264  loss_rpn_cls: 0.02454  loss_rpn_loc: 0.03677  time: 0.5912  data_time: 0.0127  lr: 0.0006993  max_mem: 6307M
# [09/16 14:24:36 d2.utils.events]:  eta: 2:18:09  iter: 719  total_loss: 0.8548  loss_cls: 0.5145  loss_box_reg: 0.3295  loss_rpn_cls: 0.02572  loss_rpn_loc: 0.03155  time: 0.5908  data_time: 0.0121  lr: 0.00071928  max_mem: 6307M
# [09/16 14:24:48 d2.utils.events]:  eta: 2:17:57  iter: 739  total_loss: 0.8598  loss_cls: 0.4665  loss_box_reg: 0.331  loss_rpn_cls: 0.02764  loss_rpn_loc: 0.02255  time: 0.5906  data_time: 0.0124  lr: 0.00073926  max_mem: 6307M
# [09/16 14:24:59 d2.utils.events]:  eta: 2:17:45  iter: 759  total_loss: 0.9492  loss_cls: 0.4889  loss_box_reg: 0.3392  loss_rpn_cls: 0.0279  loss_rpn_loc: 0.03219  time: 0.5903  data_time: 0.0129  lr: 0.00075924  max_mem: 6307M
# [09/16 14:25:11 d2.utils.events]:  eta: 2:17:33  iter: 779  total_loss: 0.8715  loss_cls: 0.4614  loss_box_reg: 0.2897  loss_rpn_cls: 0.0339  loss_rpn_loc: 0.03087  time: 0.5901  data_time: 0.0128  lr: 0.00077922  max_mem: 6307M
# [09/16 14:25:23 d2.utils.events]:  eta: 2:17:21  iter: 799  total_loss: 0.8756  loss_cls: 0.4854  loss_box_reg: 0.3031  loss_rpn_cls: 0.02714  loss_rpn_loc: 0.03011  time: 0.5898  data_time: 0.0125  lr: 0.0007992  max_mem: 6307M
# [09/16 14:25:34 d2.utils.events]:  eta: 2:17:10  iter: 819  total_loss: 0.7837  loss_cls: 0.4456  loss_box_reg: 0.279  loss_rpn_cls: 0.02827  loss_rpn_loc: 0.03225  time: 0.5896  data_time: 0.0121  lr: 0.00081918  max_mem: 6307M
# [09/16 14:25:46 d2.utils.events]:  eta: 2:16:58  iter: 839  total_loss: 0.8913  loss_cls: 0.4866  loss_box_reg: 0.3052  loss_rpn_cls: 0.02941  loss_rpn_loc: 0.02287  time: 0.5894  data_time: 0.0122  lr: 0.00083916  max_mem: 6307M
# [09/16 14:25:57 d2.utils.events]:  eta: 2:16:46  iter: 859  total_loss: 0.848  loss_cls: 0.4992  loss_box_reg: 0.3132  loss_rpn_cls: 0.02179  loss_rpn_loc: 0.02871  time: 0.5892  data_time: 0.0127  lr: 0.00085914  max_mem: 6307M
# [09/16 14:26:09 d2.utils.events]:  eta: 2:16:35  iter: 879  total_loss: 0.9355  loss_cls: 0.5122  loss_box_reg: 0.3488  loss_rpn_cls: 0.03496  loss_rpn_loc: 0.03633  time: 0.5890  data_time: 0.0137  lr: 0.00087912  max_mem: 6307M
# [09/16 14:26:21 d2.utils.events]:  eta: 2:16:23  iter: 899  total_loss: 0.7404  loss_cls: 0.4371  loss_box_reg: 0.2914  loss_rpn_cls: 0.03398  loss_rpn_loc: 0.02707  time: 0.5889  data_time: 0.0145  lr: 0.0008991  max_mem: 6307M
# [09/16 14:26:32 d2.utils.events]:  eta: 2:16:12  iter: 919  total_loss: 0.847  loss_cls: 0.5229  loss_box_reg: 0.3307  loss_rpn_cls: 0.02387  loss_rpn_loc: 0.02124  time: 0.5888  data_time: 0.0120  lr: 0.00091908  max_mem: 6307M
# [09/16 14:26:44 d2.utils.events]:  eta: 2:16:00  iter: 939  total_loss: 0.9795  loss_cls: 0.5406  loss_box_reg: 0.3183  loss_rpn_cls: 0.02604  loss_rpn_loc: 0.02308  time: 0.5886  data_time: 0.0123  lr: 0.00093906  max_mem: 6307M
# [09/16 14:26:56 d2.utils.events]:  eta: 2:15:48  iter: 959  total_loss: 0.9052  loss_cls: 0.4888  loss_box_reg: 0.3266  loss_rpn_cls: 0.03158  loss_rpn_loc: 0.04231  time: 0.5884  data_time: 0.0124  lr: 0.00095904  max_mem: 6307M
# [09/16 14:27:07 d2.utils.events]:  eta: 2:15:37  iter: 979  total_loss: 0.8726  loss_cls: 0.4983  loss_box_reg: 0.3243  loss_rpn_cls: 0.03021  loss_rpn_loc: 0.03203  time: 0.5883  data_time: 0.0136  lr: 0.00097902  max_mem: 6307M
# [09/16 14:27:19 d2.utils.events]:  eta: 2:15:26  iter: 999  total_loss: 0.8271  loss_cls: 0.4797  loss_box_reg: 0.3069  loss_rpn_cls: 0.01968  loss_rpn_loc: 0.02591  time: 0.5882  data_time: 0.0126  lr: 0.000999  max_mem: 6307M
# [09/16 14:27:31 d2.utils.events]:  eta: 2:15:14  iter: 1019  total_loss: 0.8783  loss_cls: 0.4417  loss_box_reg: 0.3346  loss_rpn_cls: 0.03121  loss_rpn_loc: 0.03204  time: 0.5881  data_time: 0.0128  lr: 0.001  max_mem: 6307M
# [09/16 14:27:43 d2.utils.events]:  eta: 2:15:02  iter: 1039  total_loss: 0.7761  loss_cls: 0.4421  loss_box_reg: 0.2723  loss_rpn_cls: 0.02481  loss_rpn_loc: 0.02812  time: 0.5882  data_time: 0.0126  lr: 0.001  max_mem: 6307M
# [09/16 14:27:54 d2.utils.events]:  eta: 2:14:52  iter: 1059  total_loss: 0.8623  loss_cls: 0.4795  loss_box_reg: 0.3212  loss_rpn_cls: 0.03236  loss_rpn_loc: 0.02184  time: 0.5882  data_time: 0.0128  lr: 0.001  max_mem: 6307M
# [09/16 14:28:06 d2.utils.events]:  eta: 2:14:41  iter: 1079  total_loss: 0.8496  loss_cls: 0.4653  loss_box_reg: 0.3518  loss_rpn_cls: 0.02918  loss_rpn_loc: 0.04887  time: 0.5881  data_time: 0.0131  lr: 0.001  max_mem: 6307M
# [09/16 14:28:18 d2.utils.events]:  eta: 2:14:30  iter: 1099  total_loss: 0.9173  loss_cls: 0.5221  loss_box_reg: 0.293  loss_rpn_cls: 0.02676  loss_rpn_loc: 0.03022  time: 0.5881  data_time: 0.0138  lr: 0.001  max_mem: 6307M
# [09/16 14:28:29 d2.utils.events]:  eta: 2:14:19  iter: 1119  total_loss: 0.8976  loss_cls: 0.4613  loss_box_reg: 0.3427  loss_rpn_cls: 0.03089  loss_rpn_loc: 0.02419  time: 0.5880  data_time: 0.0154  lr: 0.001  max_mem: 6307M
# [09/16 14:28:41 d2.utils.events]:  eta: 2:14:07  iter: 1139  total_loss: 0.8966  loss_cls: 0.4644  loss_box_reg: 0.2949  loss_rpn_cls: 0.02219  loss_rpn_loc: 0.02081  time: 0.5879  data_time: 0.0126  lr: 0.001  max_mem: 6307M
# [09/16 14:28:53 d2.utils.events]:  eta: 2:13:55  iter: 1159  total_loss: 0.8623  loss_cls: 0.4701  loss_box_reg: 0.338  loss_rpn_cls: 0.02696  loss_rpn_loc: 0.02671  time: 0.5877  data_time: 0.0123  lr: 0.001  max_mem: 6307M
# [09/16 14:29:04 d2.utils.events]:  eta: 2:13:43  iter: 1179  total_loss: 0.8068  loss_cls: 0.4802  loss_box_reg: 0.308  loss_rpn_cls: 0.01624  loss_rpn_loc: 0.02383  time: 0.5876  data_time: 0.0127  lr: 0.001  max_mem: 6307M
# [09/16 14:29:16 d2.utils.events]:  eta: 2:13:31  iter: 1199  total_loss: 0.8317  loss_cls: 0.4754  loss_box_reg: 0.2859  loss_rpn_cls: 0.01853  loss_rpn_loc: 0.03093  time: 0.5875  data_time: 0.0125  lr: 0.001  max_mem: 6307M
# [09/16 14:29:28 d2.utils.events]:  eta: 2:13:18  iter: 1219  total_loss: 0.8468  loss_cls: 0.454  loss_box_reg: 0.3176  loss_rpn_cls: 0.0273  loss_rpn_loc: 0.02761  time: 0.5874  data_time: 0.0130  lr: 0.001  max_mem: 6307M
# [09/16 14:29:39 d2.utils.events]:  eta: 2:13:06  iter: 1239  total_loss: 0.7639  loss_cls: 0.4196  loss_box_reg: 0.2697  loss_rpn_cls: 0.03013  loss_rpn_loc: 0.03027  time: 0.5873  data_time: 0.0122  lr: 0.001  max_mem: 6307M
# [09/16 14:29:51 d2.utils.events]:  eta: 2:12:52  iter: 1259  total_loss: 0.8387  loss_cls: 0.4768  loss_box_reg: 0.3394  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.01541  time: 0.5871  data_time: 0.0123  lr: 0.001  max_mem: 6307M
# [09/16 14:30:02 d2.utils.events]:  eta: 2:12:40  iter: 1279  total_loss: 0.7121  loss_cls: 0.3991  loss_box_reg: 0.2617  loss_rpn_cls: 0.02807  loss_rpn_loc: 0.01539  time: 0.5871  data_time: 0.0133  lr: 0.001  max_mem: 6307M
# [09/16 14:30:14 d2.utils.events]:  eta: 2:12:29  iter: 1299  total_loss: 0.7753  loss_cls: 0.4366  loss_box_reg: 0.2966  loss_rpn_cls: 0.01993  loss_rpn_loc: 0.01786  time: 0.5870  data_time: 0.0129  lr: 0.001  max_mem: 6307M
# [09/16 14:30:26 d2.utils.events]:  eta: 2:12:17  iter: 1319  total_loss: 0.8214  loss_cls: 0.4367  loss_box_reg: 0.2787  loss_rpn_cls: 0.0185  loss_rpn_loc: 0.02514  time: 0.5869  data_time: 0.0122  lr: 0.001  max_mem: 6307M
# [09/16 14:30:37 d2.utils.events]:  eta: 2:12:06  iter: 1339  total_loss: 0.7886  loss_cls: 0.436  loss_box_reg: 0.3032  loss_rpn_cls: 0.01811  loss_rpn_loc: 0.01827  time: 0.5868  data_time: 0.0123  lr: 0.001  max_mem: 6307M
# [09/16 14:30:49 d2.utils.events]:  eta: 2:11:53  iter: 1359  total_loss: 0.7265  loss_cls: 0.3897  loss_box_reg: 0.2633  loss_rpn_cls: 0.01676  loss_rpn_loc: 0.01949  time: 0.5867  data_time: 0.0123  lr: 0.001  max_mem: 6307M
# [09/16 14:31:01 d2.utils.events]:  eta: 2:11:41  iter: 1379  total_loss: 0.751  loss_cls: 0.4068  loss_box_reg: 0.2583  loss_rpn_cls: 0.02426  loss_rpn_loc: 0.02533  time: 0.5866  data_time: 0.0126  lr: 0.001  max_mem: 6307M
# [09/16 14:31:12 d2.utils.events]:  eta: 2:11:30  iter: 1399  total_loss: 0.885  loss_cls: 0.4726  loss_box_reg: 0.3299  loss_rpn_cls: 0.01952  loss_rpn_loc: 0.02803  time: 0.5865  data_time: 0.0124  lr: 0.001  max_mem: 6307M
# [09/16 14:31:24 d2.utils.events]:  eta: 2:11:18  iter: 1419  total_loss: 0.6155  loss_cls: 0.3625  loss_box_reg: 0.2718  loss_rpn_cls: 0.01124  loss_rpn_loc: 0.01384  time: 0.5864  data_time: 0.0124  lr: 0.001  max_mem: 6307M
# [09/16 14:31:35 d2.utils.events]:  eta: 2:11:06  iter: 1439  total_loss: 0.8386  loss_cls: 0.4307  loss_box_reg: 0.3354  loss_rpn_cls: 0.02291  loss_rpn_loc: 0.02842  time: 0.5864  data_time: 0.0121  lr: 0.001  max_mem: 6307M
# [09/16 14:31:47 d2.utils.events]:  eta: 2:10:55  iter: 1459  total_loss: 0.6694  loss_cls: 0.3732  loss_box_reg: 0.2485  loss_rpn_cls: 0.0228  loss_rpn_loc: 0.0182  time: 0.5863  data_time: 0.0124  lr: 0.001  max_mem: 6307M
# [09/16 14:31:59 d2.utils.events]:  eta: 2:10:43  iter: 1479  total_loss: 0.7348  loss_cls: 0.4132  loss_box_reg: 0.2766  loss_rpn_cls: 0.01723  loss_rpn_loc: 0.01992  time: 0.5862  data_time: 0.0129  lr: 0.001  max_mem: 6307M
# [09/16 14:32:10 d2.utils.events]:  eta: 2:10:32  iter: 1499  total_loss: 0.9484  loss_cls: 0.4847  loss_box_reg: 0.3475  loss_rpn_cls: 0.0279  loss_rpn_loc: 0.03441  time: 0.5862  data_time: 0.0134  lr: 0.001  max_mem: 6307M
# [09/16 14:32:22 d2.utils.events]:  eta: 2:10:20  iter: 1519  total_loss: 0.7265  loss_cls: 0.4374  loss_box_reg: 0.262  loss_rpn_cls: 0.02269  loss_rpn_loc: 0.02714  time: 0.5862  data_time: 0.0135  lr: 0.001  max_mem: 6307M
# [09/16 14:32:34 d2.utils.events]:  eta: 2:10:09  iter: 1539  total_loss: 0.839  loss_cls: 0.4439  loss_box_reg: 0.3416  loss_rpn_cls: 0.02758  loss_rpn_loc: 0.03207  time: 0.5861  data_time: 0.0121  lr: 0.001  max_mem: 6307M
# [09/16 14:32:45 d2.utils.events]:  eta: 2:09:57  iter: 1559  total_loss: 0.7037  loss_cls: 0.4124  loss_box_reg: 0.261  loss_rpn_cls: 0.01672  loss_rpn_loc: 0.01745  time: 0.5860  data_time: 0.0124  lr: 0.001  max_mem: 6307M
# [09/16 14:32:57 d2.utils.events]:  eta: 2:09:44  iter: 1579  total_loss: 0.8431  loss_cls: 0.4497  loss_box_reg: 0.3388  loss_rpn_cls: 0.02479  loss_rpn_loc: 0.02983  time: 0.5859  data_time: 0.0126  lr: 0.001  max_mem: 6307M
# [09/16 14:33:09 d2.utils.events]:  eta: 2:09:33  iter: 1599  total_loss: 0.9161  loss_cls: 0.4729  loss_box_reg: 0.3653  loss_rpn_cls: 0.03634  loss_rpn_loc: 0.03134  time: 0.5858  data_time: 0.0127  lr: 0.001  max_mem: 6307M
# [09/16 14:33:20 d2.utils.events]:  eta: 2:09:22  iter: 1619  total_loss: 0.7929  loss_cls: 0.4037  loss_box_reg: 0.3316  loss_rpn_cls: 0.02594  loss_rpn_loc: 0.03542  time: 0.5857  data_time: 0.0125  lr: 0.001  max_mem: 6307M
# [09/16 14:33:32 d2.utils.events]:  eta: 2:09:11  iter: 1639  total_loss: 0.6438  loss_cls: 0.3523  loss_box_reg: 0.2697  loss_rpn_cls: 0.01485  loss_rpn_loc: 0.01866  time: 0.5857  data_time: 0.0122  lr: 0.001  max_mem: 6307M
# [09/16 14:33:43 d2.utils.events]:  eta: 2:08:59  iter: 1659  total_loss: 0.6848  loss_cls: 0.3806  loss_box_reg: 0.2736  loss_rpn_cls: 0.0143  loss_rpn_loc: 0.01377  time: 0.5856  data_time: 0.0126  lr: 0.001  max_mem: 6307M
# [09/16 14:33:55 d2.utils.events]:  eta: 2:08:48  iter: 1679  total_loss: 0.7186  loss_cls: 0.4053  loss_box_reg: 0.2831  loss_rpn_cls: 0.01412  loss_rpn_loc: 0.02394  time: 0.5856  data_time: 0.0130  lr: 0.001  max_mem: 6307M
# [09/16 14:34:07 d2.utils.events]:  eta: 2:08:37  iter: 1699  total_loss: 0.7351  loss_cls: 0.373  loss_box_reg: 0.2671  loss_rpn_cls: 0.01788  loss_rpn_loc: 0.01888  time: 0.5855  data_time: 0.0123  lr: 0.001  max_mem: 6307M
